# %%
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
### 출력 영상 크기
plt.rcParams["figure.figsize"] = (16,9)
### 한글 표시
plt.rcParams["font.family"] = 'Gulim'

# %%
### 영상 읽기
img_file = r"C:\Users\kr937\Desktop\2023\2023\Image processing\lena.png"

# %%
img_lena = cv2.imread(r"C:\Users\kr937\Desktop\2023\2023\Image processing\lena.png")

# %%
img_lena.shape
# Out:
# (512, 512, 3)

# %%
### openCV window
cv2.imshow("Display window", img_lena)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
### 영상 출력 - color
img_rgb = cv2.cvtColor(img_lena, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
### Color 영상을 Grayscale 영상으로 변환
img_gray = cv2.cvtColor(img_lena, cv2.COLOR_BGR2GRAY)
img_gray.shape
# Out:
# (512, 512)

# %%
### 영상 출력 - gray
plt.imshow(img_gray, 'gray')
plt.show()

# %%
type(img_lena), img_raw.dtype, img_lena.shape
# Out:
# (numpy.ndarray, dtype('uint8'), (512, 512, 3))

# %%
img_lena[:, :, 0]
# Out:
# array([[125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        [125, 125, 133, ..., 122, 110,  90],
#        ...,
#        [ 60,  60,  58, ...,  84,  76,  79],
#        [ 57,  57,  62, ...,  79,  81,  81],
#        [ 57,  57,  62, ...,  79,  81,  81]], dtype=uint8)
